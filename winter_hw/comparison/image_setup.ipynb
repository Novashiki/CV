# %% [markdown]
# ## CV Winter Vacation HomeWork

# %%
from PIL import Image
import numpy as np

# %%
lena = Image.open("lena.jpg").convert("L")
lena_arr = np.array(lena)
np.save("lena.npy", lena_arr)

# %%
cameraman = Image.open("cameraman.jpg").convert("L")
cameraman_arr = np.array(cameraman)
np.save("cameraman.npy", cameraman_arr)

# %%
print("Lena Shape: ", lena_arr.shape)
# Out:
# Lena Shape:  (512, 512)

# %%
print("Cameraman shape: ", cameraman_arr.shape)
# Out:
# Cameraman shape:  (256, 256)
